# %% [markdown]
# # 0.0 Imports

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # 1.0 Projeto Olist - Perguntas Semana 6

# %% [markdown]
# 1. Quantos clientes únicos tiveram seu pedidos com status de “processing”, “shipped” e “delivered”, feitos entre os dias 01 e 31 de Outubro de 2016. Mostrar o resultado somente se o número total de clientes for acima de 5.
#
# 2. Mostre a quantidade total dos pedidos e o valor total do pagamento, para pagamentos entre 1 e 5 prestações ou um valor de pagamento acima de 5000 reais.
#
# 3. Quantos produtos estão cadastrados nas categorias: perfumaria, brinquedos, esporte lazer e cama mesa, que possuem entre 5 e 10 fotos, um peso que não está entre 1 e 5 g, um altura maior que 10 cm, uma largura maior que 20 cm. Mostra somente as linhas com mais de 10 produtos únicos.
#
# 4. Qual a quantidade de cidades únicas dos vendedores no estado de São Paulo ou Rio de Janeiro com a latitude maior que -24.54 e longitude menor que -45.63?
#
# 5. Quantos produtos estão cadastrados em qualquer categorias que comece com a letra “a” e termine com a letra “o” e que possuem mais de 5 fotos? Mostrar as linhas com mais de 10 produtos.
#
# 6. Qual o número de clientes únicos, agrupados por estado e por cidades que comecem com a letra “m”, tem a letra “o” e terminem com a letra “a”? Mostrar os resultados somente para o número de clientes únicos maior que 10.

# %% [markdown]
# ##  1. Quantos clientes únicos tiveram seu pedidos com status de “processing”, “shipped” e “delivered”, feitos entre os dias 01 e 31 de Outubro de 2016. Mostrar o resultado somente se o número total de clientes for acima de 5.

# %%
Image( "./imagens/week_6_per_1_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_6_per_1_1_1.png")

# %%
Image( "./imagens/week_6_per_1_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_6_per_1_3.png")

# %% [markdown]
# ## 2. Mostre a quantidade total dos pedidos e o valor total do pagamento, para pagamentos entre 1 e 5 prestações ou um valor de pagamento acima de 5000 reais.

# %%
Image( "./imagens/week_6_per_2_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_6_per_2_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_6_per_2_3.png")

# %% [markdown]
# ## 3. Quantos produtos estão cadastrados nas categorias: perfumaria, brinquedos, esporte lazer e cama mesa, que possuem entre 5 e 10 fotos, um peso que não está entre 1 e 5 g, um altura maior que 10 cm, uma largura maior que 20 cm. Mostra somente as linhas com mais de 10 produtos únicos.

# %%
Image( "./imagens/week_6_per_3_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_6_per_3_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_6_per_3_3.png")

# %% [markdown]
# ## 4. Qual a quantidade de cidades únicas dos vendedores no estado de São Paulo ou Rio de Janeiro com a latitude maior que -24.54 e longitude menor que -45.63?

# %%
Image( "./imagens/week_6_per_4_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_6_per_4_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_6_per_4_3.png")

# %% [markdown]
# ## 5. Quantos produtos estão cadastrados em qualquer categorias que comece com a letra “a” e termine com a letra “o” e que possuem mais de 5 fotos? Mostrar as linhas com mais de 10 produtos.

# %%
Image( "./imagens/week_6_per_5_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_6_per_5_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_6_per_5_3.png")

# %% [markdown]
# ## 6. Qual o número de clientes únicos, agrupados por estado e por cidades que comecem com a letra “m”, tem a letra “o” e terminem com a letra “a”? Mostrar os resultados somente para o número de clientes únicos maior que 10.

# %%
Image( "./imagens/week_6_per_6_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_6_per_6_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_6_per_6_3.png")
