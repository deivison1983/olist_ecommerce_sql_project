# %% [markdown]
# # 0.0 Imports

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # 1.0 Projeto Olist - Perguntas Semana 5

# %% [markdown]
# 1. Qual o número de clientes únicos nos estado de Minas Gerais ou Rio de Janeiro?
#
# 2. Qual a quantidade de cidades únicas dos vendedores no estado de São Paulo ou Rio de Janeiro com a latitude maior que -24.54 e longitude menor que -45.63?
#
# 3. Qual o número total de pedidos únicos, o número total de produtos e o preço médio dos pedidos com o preço de frete maior que 20 reais e a data limite de envio entre os dias 1 e 31 de Outubro de 2016?
#
# 4. Mostre a quantidade total dos pedidos e o valor total do pagamento, para pagamentos entre 1 e 5 prestações ou um valor de pagamento acima de 5000 reais.
#
# 5. Qual a quantidade de pedidos com o status em processamento ou cancelada acontecem com a data estimada de entrega maior que 01 de Janeiro de 2017 ou menor que 23 de Novembro de 2016?
#
# 6. Quantos produtos estão cadastrados nas categorias: perfumaria, brinquedos, esporte lazer, cama mesa e banho e móveis de escritório que possuem mais de 5 fotos, um peso maior que 5 g, um altura maior que 10 cm, uma largura maior que 20 cm?

# %% [markdown]
# ## 1. Qual o número de clientes únicos nos estado de Minas Gerais ou Rio de Janeiro?

# %%
Image( "./imagens/week_5_per_1_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_1_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_1_3.png")

# %% [markdown]
# ## 2. Qual a quantidade de cidades únicas dos vendedores no estado de São Paulo ou Rio de Janeiro com a latitude maior que -24.54 e longitude menor que -45.63?

# %%
Image( "./imagens/week_5_per_2_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_2_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_2_3.png")

# %% [markdown]
# ## 3. Qual o número total de pedidos únicos, o número total de produtos e o preço médio dos pedidos com o preço de frete maior que 20 reais e a data limite de envio entre os dias 1 e 31 de Outubro de 2016?

# %%
Image( "./imagens/week_5_per_3_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_3_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_3_3.png")

# %% [markdown]
# ## 4. Mostre a quantidade total dos pedidos e o valor total do pagamento, para pagamentos entre 1 e 5 prestações ou um valor de pagamento acima de 5000 reais.

# %%
Image( "./imagens/week_5_per_4_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_4_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_4_3.png")

# %% [markdown]
# ## 5. Qual a quantidade de pedidos com o status em processamento ou cancelada acontecem com a data estimada de entrega maior que 01 de Janeiro de 2017 ou menor que 23 de Novembro de 2016?

# %%
Image( "./imagens/week_5_per_5_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_5_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_5_3.png")

# %% [markdown]
# ## 6. Quantos produtos estão cadastrados nas categorias: perfumaria, brinquedos, esporte lazer, cama mesa e banho e móveis de escritório que possuem mais de 5 fotos, um peso maior que 5 g, um altura maior que 10 cm, uma largura maior que 20 cm?

# %%
Image( "./imagens/week_5_per_6_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_6_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_6_3.png")

# %% [markdown]
# ## 7. Mostre a quantidade total de pedidos e o valor total de pagamento para cada tipo de pagamento entre 1 a 5 prestações ou com valor de pagamento acima de 5000 reais.

# %%
Image( "./imagens/week_5_per_7_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_5_per_7_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_5_per_7_3.png")
