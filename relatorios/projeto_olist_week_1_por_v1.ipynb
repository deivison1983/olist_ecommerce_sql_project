# %% [markdown]
# # 0.0 Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # 1.0 Projeto Olist - Perguntas Semana 1

# %% [markdown]
# 1. Gere uma tabela com o id do cliente, a cidade e o estado onde ele vive.
#
# 2. Gere uma tabela com o id do cliente e a cidade, somente dos clientes que vivem em Santa Catarina.
#
# 3. Gere uma tabela com o id do cliente e o estado, somente dos clientes que vivem em Florianópolis.
#
# 4. Gere uma tabela com o estado, latitude e longitude do estado de São Paulo.
#
# 5. Gere uma tabela com o id do produto, a data de envio e o preço, somente para produtos acima de 6300.
#
# 6. Gere uma tabela com o id do pedido, o tipo de pagamento e o número de parcelas, somente para produtos com parcelas menores que 1.
#
# 7. Gere uma tabela com o id do pedido, id do cliente, o status do pedido e a data de aprovação , somente para compras aprovadas até dia 05 de Maio de 2016.

# %% [markdown]
# ## 1. Gere uma tabela com o id do cliente, a cidade e o estado onde ele vive.

# %%
Image( "./imagens/week_1_per_1_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_1_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_1_3.png")

# %% [markdown]
# ## 2. Gere uma tabela com o id do cliente e a cidade, somente dos clientes que vivem em Santa Catarina.

# %%
Image( "./imagens/week_1_per_2_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_2_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_2_3.png")

# %% [markdown]
# ## 3. Gere uma tabela com o id do cliente e o estado, somente dos clientes que vivem em Florianópolis.

# %%
Image( "./imagens/week_1_per_3_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_3_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_3_3.png")

# %% [markdown]
# ## 4. Gere uma tabela com o estado, latitude e longitude do estado de São Paulo.

# %%
Image( "./imagens/week_1_per_4_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_4_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_4_3.png")

# %% [markdown]
# ## 5. Gere uma tabela com o id do produto, a data de envio e o preço, somente para produtos acima de 6300.

# %%
Image( "./imagens/week_1_per_5_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_5_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_5_3.png")

# %% [markdown]
# ## 6. Gere uma tabela com o id do pedido, o tipo de pagamento e o número de parcelas, somente para produtos com parcelas menores que 1.

# %%
Image( "./imagens/week_1_per_6_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_6_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_6_3.png")

# %% [markdown]
# ## 7. Gere uma tabela com o id do pedido, id do cliente, o status do pedido e a data de aprovação , somente para compras aprovadas até dia 05 de Outubro de 2016.

# %%
Image( "./imagens/week_1_per_7_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_1_per_7_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_1_per_7_3.png")
