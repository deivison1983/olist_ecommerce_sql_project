# %% [markdown]
# # 0.0 Imports

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # 1.0 Projeto Olist - Perguntas Semana 7

# %% [markdown]
# 1. Gerar uma tabela de dados com 10 linhas, contendo o id do pedido, o id do cliente, o status do pedido, o id do produto e o preço do produto.
#
# 2. Gerar uma tabela de dados com 20 linhas, contendo o id do pedido, o estado do cliente, a cidade do cliente, o status do pedido, o id do produto e o preço do produto somente para clientes do estado de São Paulo.
#
# 3. Gerar uma tabela de dados com 50 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto e o preço do produto, somente para pedidos com status igual a cancelado.
#
# 4. Gerar uma tabela de dados com 80 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto, a cidade e o estado do vendedor e a data de aprovação do pedido, somente para os pedidos aprovados a partir do dia 16 de Setembro de 2016.
#
# 5. Gerar uma tabela de dados com 10 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto, o preço do produto, a cidade e o estado do vendedor, a data de aprovação do pedido e o tipo de pagamento, somente para o tipo de pagamento igual a boleto.
#
# 6. Gerar uma tabela de dados com 70 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto, o preço do produto, a cidade e o estado do vendedor, a data de aprovação do pedido, tipo de pagamento e a nota de avaliação do produto, somente para pedidos com a nota de avaliação do produto igual a 1.

# %% [markdown]
# ##  1. Gerar uma tabela de dados com 10 linhas, contendo o id do pedido, o id do cliente, o status do pedido, o id do produto e o preço do produto.

# %%
Image( "./imagens/week_7_per_1_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_7_per_1_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_7_per_1_3.png")

# %% [markdown]
# ## 2. Gerar uma tabela de dados com 20 linhas, contendo o id do pedido, o estado do cliente, a cidade do cliente, o status do pedido, o id do produto e o preço do produto somente para clientes do estado de São Paulo.

# %%
Image( "./imagens/week_7_per_2_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_7_per_2_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_7_per_2_3.png")

# %% [markdown]
# ## 3. Gerar uma tabela de dados com 50 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto e o preço do produto, somente para pedidos com status igual a cancelado.

# %%
Image( "./imagens/week_7_per_3_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_7_per_3_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_7_per_3_3.png")

# %% [markdown]
# ## 4. Gerar uma tabela de dados com 80 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto, a cidade e o estado do vendedor e a data de aprovação do pedido, somente para os pedidos aprovados a partir do dia 16 de Setembro de 2016.

# %%
Image( "./imagens/week_7_per_4_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_7_per_4_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_7_per_4_3.png")

# %% [markdown]
# ## 5. Gerar uma tabela de dados com 10 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto, o preço do produto, a cidade e o estado do vendedor, a data de aprovação do pedido e o tipo de pagamento, somente para o tipo de pagamento igual a boleto.

# %%
Image( "./imagens/week_7_per_5_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_7_per_5_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_7_per_5_3.png")

# %% [markdown]
# ## 6. Gerar uma tabela de dados com 70 linhas, contendo o id do pedido, o estado e a cidade do cliente, o status do pedido, o nome da categoria do produto, o preço do produto, a cidade e o estado do vendedor, a data de aprovação do pedido, tipo de pagamento e a nota de avaliação do produto, somente para pedidos com a nota de avaliação do produto igual a 1.

# %%
Image( "./imagens/week_7_per_6_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_7_per_6_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_7_per_6_3.png")
