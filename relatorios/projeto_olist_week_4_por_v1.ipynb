# %% [markdown]
# # 0.0 Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec
from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# # 1.0 Projeto Olist - Perguntas Semana 4

# %% [markdown]
# 1. Qual o número de clientes únicos do estado de São Paulo?
#
# 2. Qual o número total de pedidos únicos feitos no dia 08 de Outubro de 2016?
#
# 3. Qual o número total de pedidos únicos feitos a partir do dia 08 de Outubro de 2016?
#
# 4. Qual o número total de pedidos únicos feitos a partir do dia 08 de Outubro de 2016 incluso?
#
# 5. Qual o número total de pedidos únicos, a data mínima e máxima de envio, o valor máximo, mínimo e médio do frete dos pedidos abaixo de 1.100 reais por cada vendedor?
#
# 6. Qual o número total de pedidos únicos, a data mínima e máxima de envio, o valor máximo, mínimo e médio do frete dos pedidos abaixo de 1.100 reais incluso por cada vendedor?

# %% [markdown]
# ## 1. Qual o número de clientes únicos do estado de São Paulo?

# %%
Image( "./imagens/week_4_per_1_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_4_per_1_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_4_per_1_3.png")

# %% [markdown]
# ## 2. Qual o número total de pedidos únicos feitos no dia 08 de Outubro de 2016?

# %%
Image( "./imagens/week_4_per_2_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_4_per_2_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_4_per_2_3.png")

# %% [markdown]
# ## 3. Qual o número total de pedidos únicos feitos a partir do dia 08 de Outubro de 2016?

# %%
Image( "./imagens/week_4_per_3_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_4_per_3_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_4_per_3_3.png")

# %% [markdown]
# ## 4. Qual o número total de pedidos únicos feitos a partir do dia 08 de Outubro de 2016 incluso esse dia?

# %%
Image( "./imagens/week_4_per_4_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_4_per_4_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_4_per_4_3.png")

# %% [markdown]
# ## 5. Qual o número total de pedidos únicos, a data mínima e máxima de envio, o valor máximo, mínimo e médio do frete dos pedidos abaixo ou iguais a 1.100 reais por cada vendedor?

# %%
Image( "./imagens/week_4_per_5_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_4_per_5_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_4_per_5_3.png")

# %% [markdown]
# ## 6. Qual o número total de pedidos únicos, a data mínima e máxima de envio, o valor máximo, mínimo e médio do frete dos pedidos iguais a 1.100 reais incluso por cada vendedor?

# %%
Image( "./imagens/week_4_per_6_1.png")

# %% [markdown]
# **DETALHE DA QUERY**

# %%
Image( "./imagens/week_4_per_6_2.png")

# %% [markdown]
# **DETALHE DO RESULTADO DA CONSULTA**

# %%
Image( "./imagens/week_4_per_6_3.png")
